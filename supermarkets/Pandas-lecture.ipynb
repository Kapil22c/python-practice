# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Untitled.ipynb']

# %%
import pandas as pd

# %%
df1 = pd.read_csv("supermarket.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-6e6880ecd067> in <module>
# ----> 1 df1 = pd.read_csv("supermarket.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
# ...

# %%
df1 = pd.read_csv("supermarkets.csv")

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df2 = pd.read_json('supermarkets.json')

# %%
df2.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df3 = pd.read_excel("supermarkets.xlsx", sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df3.set_index("ID")
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df4 = pd.read_csv('supermarkets-commas.txt')
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4.set_index('ID')
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df5 = pd.read_csv('supermarkets-semi-colons.txt')
df5
# Out:
#         ID;Address;City;State;Country;Name;Employees
# 0  1;3666 21st St;San Francisco;CA 94114;USA;Made...
# 1  2;735 Dolores St;San Francisco;CA 94119;USA;Br...
# 2  3;332 Hill St;San Francisco;California 94114;U...
# 3  4;3995 23rd St;San Francisco;CA 94114;USA;Ben'...
# 4  5;1056 Sanchez St;San Francisco;California;USA...
# 5  6;551 Alvarado St;San Francisco;CA 94114;USA;R...

# %%
df5 = pd.read_csv('supermarkets-semi-colons.txt', sep=";")
df5.set_index('ID')
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
# 2 Ways for set index
df6 = df5.set_index('ID')
df6
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
# or this .. but be very careful in this
df5.set_index("City", inplace=True)
df5
# Out:
#                           State Country          Name  Employees
# City
# San Francisco          CA 94114     USA       Madeira          8
# San Francisco          CA 94119     USA   Bready Shop         15
# San Francisco  California 94114     USA   Super River         25
# San Francisco          CA 94114     USA    Ben's Shop         10
# San Francisco        California     USA       Sanchez         12
# San Francisco          CA 94114     USA    Richvalley         20

# %%
df5.set_index("Name", inplace=True, drop=False)
df5
# See name column is not deleted

# Use that storing in variable method
# Out:
#                          State Country          Name  Employees
# Name
# Madeira               CA 94114     USA       Madeira          8
# Bready Shop           CA 94119     USA   Bready Shop         15
#  Super River  California 94114     USA   Super River         25
# Ben's Shop            CA 94114     USA    Ben's Shop         10
# Sanchez             California     USA       Sanchez         12
# Richvalley            CA 94114     USA    Richvalley         20

# %%
df6 = df6.set_index("Address")
df6
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-8006dce825ef> in <module>
# ----> 1 df6 = df6.set_index("Address")
#       2 df6
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Address'] are in the columns"

# %%
df7 = pd.read_csv("supermarkets.csv")
df7
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7 = df7.set_index('ID')
df7
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7.loc["2":"4","State":"Name"]
# here lower bound doesn't exclude
# Out:
#                State Country         Name
# ID
# 2           CA 94119     USA  Bready Shop
# 3   California 94114     USA  Super River
# 4           CA 94114     USA   Ben's Shop

# %%
df7.loc[4,"State"]
# Out:
# 'CA 94114'

# %%
df7.loc[:,"State"]
# Out:
# ID
# 1            CA 94114
# 2            CA 94119
# 3    California 94114
# 4            CA 94114
# 5          California
# 6            CA 94114
# Name: State, dtype: object

# %%
list(df7.loc[:,"State"])
# Out:
# ['CA 94114',
#  'CA 94119',
#  'California 94114',
#  'CA 94114',
#  'California',
#  'CA 94114']

# %%
list(df7.loc[4,"State"])
# Out:
# ['C', 'A', ' ', '9', '4', '1', '1', '4']

# %%
df7
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7.iloc[2:4,2:5]
# it's all about index...
# here lower bound is excludes
# Out:
#                State Country         Name
# ID
# 3   California 94114     USA  Super River
# 4           CA 94114     USA   Ben's Shop

# %%
df7.iloc[:,2:5]
# Out:
#                State Country         Name
# ID
# 1           CA 94114     USA      Madeira
# 2           CA 94119     USA  Bready Shop
# 3   California 94114     USA  Super River
# 4           CA 94114     USA   Ben's Shop
# 5         California     USA      Sanchez
# 6           CA 94114     USA   Richvalley

# %%
df7.iloc[3,2:5]
# Out:
# State        CA 94114
# Country           USA
# Name       Ben's Shop
# Name: 4, dtype: object

# %%
list(df7.iloc[3,2:5])
# Out:
# ['CA 94114', 'USA', "Ben's Shop"]

# %%
# for delete use drop... in argument pass 0 for delete of row or pass 1 for delete column
df7
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7.drop("City",1)
# pass column header name and 1 for delete whole column
# Out:
#             Address             State Country         Name  Employees
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 2    735 Dolores St          CA 94119     USA  Bready Shop         15
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df7.drop(2,0)
# pass row header name and 0 for delete row... note that deleted column is still visible..
# because you haven't store that query in a variable...
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df7
# don't confuse ... I have stored that queries but I have deleted it.
# Out:
#             Address             State Country         Name  Employees
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df7.drop(df7.index[0:3],0)
# row deleted 1,3 and 4..  0,1,2 and 3 is excluded
# Out:
#             Address       State Country        Name  Employees
# ID
# 5   1056 Sanchez St  California     USA     Sanchez         12
# 6   551 Alvarado St    CA 94114     USA  Richvalley         20

# %%
df7.drop(df7.columns[0:3],1)
# again I haven't store query this time... so deleted row can be still visible
# Out:
#            Name  Employees
# ID
# 1       Madeira          8
# 3   Super River         25
# 4    Ben's Shop         10
# 5       Sanchez         12
# 6    Richvalley         20

# %%
df7.columns
# Out:
# Index(['Address', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
df7
# Out:
#             Address             State Country         Name  Employees
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
len(df7.index)
# Out:
# 5

# %%
len(df7.columns)
# Out:
# 5

# %%
# for adding new columns or rows....
df7['Continents'] = df7.shape[0]*['North America']
df7
# Out:
#             Address             State Country         Name  Employees  \
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20
#
#        Continents
# ID
# 1   North America
# 3   North America
# 4   North America
# 5   North America
# 6   North America

# %%
df7.shape
# Out:
# (5, 6)

# %%
df7.shape[0]
# so 5 times north america were added..
# Out:
# 5

# %%
df7['Continents'] = df7['Country']+","+ "North America"

# %%
df7
# Out:
#             Address             State Country         Name  Employees  \
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20
#
#            Continents
# ID
# 1   USA,North America
# 3   USA,North America
# 4   USA,North America
# 5   USA,North America
# 6   USA,North America

# %%
df7['Continents'] = df7['Country']+","+ "North America" +","+ df7['State']
df7
# Out:
#             Address             State Country         Name  Employees  \
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20
#
#                             Continents
# ID
# 1           USA,North America,CA 94114
# 3   USA,North America,California 94114
# 4           USA,North America,CA 94114
# 5         USA,North America,California
# 6           USA,North America,CA 94114

# %%
# Now we transpose whole data for adding a row...
df7_t = df7.T

# %%
df7_t
# Out:
# ID                                   1                                   3  \
# Address                   3666 21st St                         332 Hill St
# State                         CA 94114                    California 94114
# Country                            USA                                 USA
# Name                           Madeira                         Super River
# Employees                            8                                  25
# Continents  USA,North America,CA 94114  USA,North America,California 94114
#
# ID                                   4                             5  \
# Address                   3995 23rd St               1056 Sanchez St
# State                         CA 94114                    California
# Country                            USA                           USA
# Name                        Ben's Shop                       Sanchez
# Employees                           10                            12
# ...

# %%
#df7_t[7] = ["My Address", "My State", " My Country"," My name",80, "My continent"] --- This is main
df7_t[1] = ["My Address", "My State", " My Country"," My name",80, "My continent"]

# %%
df7_t
# Out:
# ID                     1                                   3  \
# Address       My Address                         332 Hill St
# State           My State                    California 94114
# Country       My Country                                 USA
# Name             My name                         Super River
# Employees             80                                  25
# Continents  My continent  USA,North America,California 94114
#
# ID                                   4                             5  \
# Address                   3995 23rd St               1056 Sanchez St
# State                         CA 94114                    California
# Country                            USA                           USA
# Name                        Ben's Shop                       Sanchez
# Employees                           10                            12
# Continents  USA,North America,CA 94114  USA,North America,California
#
# ...

# %%
df7 = df7_t.T

# %%
df7
# Out:
#             Address             State      Country         Name Employees  \
# ID
# 1        My Address          My State   My Country      My name        80
# 3       332 Hill St  California 94114          USA  Super River        25
# 4      3995 23rd St          CA 94114          USA   Ben's Shop        10
# 5   1056 Sanchez St        California          USA      Sanchez        12
# 6   551 Alvarado St          CA 94114          USA   Richvalley        20
# 7        My Address          My State   My Country      My name        80
#
#                             Continents
# ID
# 1                         My continent
# 3   USA,North America,California 94114
# 4           USA,North America,CA 94114
# 5         USA,North America,California
# 6           USA,North America,CA 94114
# 7                         My continent

# %%
df7.drop(7,0)
# looking cool huh...
# Out:
#             Address             State      Country         Name Employees  \
# ID
# 1        My Address          My State   My Country      My name        80
# 3       332 Hill St  California 94114          USA  Super River        25
# 4      3995 23rd St          CA 94114          USA   Ben's Shop        10
# 5   1056 Sanchez St        California          USA      Sanchez        12
# 6   551 Alvarado St          CA 94114          USA   Richvalley        20
#
#                             Continents
# ID
# 1                         My continent
# 3   USA,North America,California 94114
# 4           USA,North America,CA 94114
# 5         USA,North America,California
# 6           USA,North America,CA 94114
